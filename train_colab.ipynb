# %%
# !pip install -q albumentations tabulate segmentation-models-pytorch

# %%
# !git clone https://github.com/Eymeee/crack-seg-kd.git
# %cd crack-seg-kd
# Out:
# Cloning into 'crack-seg-kd'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 29 (delta 9), reused 27 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (29/29), 17.95 KiB | 17.95 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
# /kaggle/working/crack-seg-kd/crack-seg-kd/crack-seg-kd

# %%
import os, shutil, random

base     = '/kaggle/input/datasets/lakshaymiddha/crack-segmentation-dataset/crack_segmentation_dataset'
src_images = f'{base}/images'
src_masks  = f'{base}/masks'

random.seed(42)
files = sorted(os.listdir(src_images))
random.shuffle(files)

n       = len(files)
n_train = int(n * 0.70)
n_val   = int(n * 0.15)

splits = {
    'train' : files[:n_train],
    'val'   : files[n_train:n_train + n_val],
    'test'  : files[n_train + n_val:],
}

for split, subset in splits.items():
    os.makedirs(f'data/{split}/images', exist_ok=True)
    os.makedirs(f'data/{split}/masks',  exist_ok=True)
    for f in subset:
        mask_f = f if os.path.exists(f'{src_masks}/{f}') else f.replace('.jpg', '.png')
        shutil.copy(f'{src_images}/{f}',     f'data/{split}/images/{f}')
        shutil.copy(f'{src_masks}/{mask_f}', f'data/{split}/masks/{mask_f}')
    print(f'{split}: {len(subset)} images')
# Out:
# train: 7908 images
# val: 1694 images
# test: 1696 images

# %%
# !python src/dataset.py
# Out:
# [train] 7908 images chargées
# [val] 1694 images chargées
# [test] 1696 images chargées
# Batch images : torch.Size([4, 3, 512, 512])
# Batch masques : torch.Size([4, 1, 512, 512])
# Valeurs masque : tensor([0., 1.])

# %%
# !python src/train.py --mode teacher --epochs 15 --batch_size 4 --img_size 512
# Out:
#   Device : cuda
# [train] 7908 images chargées
# [val] 1694 images chargées
# [test] 1696 images chargées
#
# ...
#   MODE : TEACHER (U-Net++)
# ...
#   Epoch [001/15]  Loss: 0.3091  IoU: 0.4970  F1: 0.6311
#   ✓ Checkpoint sauvegardé → checkpoints/teacher_best.pth
#   Epoch [002/15]  Loss: 0.2257  IoU: 0.5328  F1: 0.6620
#   ✓ Checkpoint sauvegardé → checkpoints/teacher_best.pth
#   Epoch [003/15]  Loss: 0.2139  IoU: 0.5300  F1: 0.6618
#   Epoch [004/15]  Loss: 0.2103  IoU: 0.5621  F1: 0.6915
#   ✓ Checkpoint sauvegardé → checkpoints/teacher_best.pth
#   Epoch [005/15]  Loss: 0.2057  IoU: 0.5663  F1: 0.6959
#   ✓ Checkpoint sauvegardé → checkpoints/teacher_best.pth
#   Epoch [006/15]  Loss: 0.2030  IoU: 0.5308  F1: 0.6622
#   Epoch [007/15]  Loss: 0.1994  IoU: 0.5667  F1: 0.6967
#   ✓ Checkpoint sauvegardé → checkpoints/teacher_best.pth
#   Epoch [008/15]  Loss: 0.1956  IoU: 0.5828  F1: 0.7132
#   ✓ Checkpoint sauvegardé → checkpoints/teacher_best.pth
# ...
